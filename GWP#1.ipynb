# %%
import pandas as pd

df = pd.read_csv ('GWP.csv')
print (df)
# Out:
#           Date     LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA  \
# 0     1-Jan-16  1390.716         2376.29          3525.9150         1068.79
# 1     8-Jan-16  1291.267         2260.85          3280.6683         1005.56
# 2    15-Jan-16  1257.086         2217.50          3118.2981          985.38
# 3    22-Jan-16  1254.167         2281.98          2935.0677          985.87
# 4    29-Jan-16  1298.240         2462.19          3134.0840         1005.56
# ..         ...       ...             ...                ...             ...
# 247  25-Sep-20   988.345         1450.64          2252.2500         1166.97
# 248   2-Oct-20  1037.211         1506.32          2265.7000         1128.45
# 249   9-Oct-20  1075.670         1617.45          2214.3200         1187.29
# 250  16-Oct-20  1068.089         1628.12          2194.6300         1200.97
# 251  23-Oct-20  1090.573         1618.83          2185.5500         1201.19
#
# ...

# %%
df.mean()
# Out:
# C:\Users\ITS\AppData\Local\Temp/ipykernel_2252/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# LUXXX                      1457.231905
# MSCI ARGENTINA             2526.652262
# BLP ORIENTE MEDIO          3029.482978
# MSCI AUSTRALIA             1183.940159
# MSCI AUSTRIA                127.418889
# MSCI BELGIUM                 91.290238
# MSCI BRAZIL                1813.989167
# MSCI CANADA                1970.821627
# MSCI CHINA                   76.788214
# MSCI DENMARK               8447.657738
# MSCI EM ASIA                509.413056
# MSCI EM EU-MIDE-AFRICA      247.079409
# MSCI EM EUROPE              304.084643
# MSCI EM LATIN AMERICA      2502.462738
# MSCI FINLAND                121.925278
# MSCI FRANCE                 145.765476
# MSCI GERMANY                143.522897
# ...

# %%
df.mean(axis = 1)[0:5]
# Out:
# C:\Users\ITS\AppData\Local\Temp/ipykernel_2252/369270116.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean(axis = 1)[0:5]
# 0    1873.906289
# 1    1758.680351
# 2    1699.141289
# 3    1711.253020
# 4    1767.651143
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\ITS\AppData\Local\Temp/ipykernel_2252/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# LUXXX                      1491.08100
# MSCI ARGENTINA             2541.97500
# BLP ORIENTE MEDIO          3113.41405
# MSCI AUSTRALIA             1177.37500
# MSCI AUSTRIA                130.63500
# MSCI BELGIUM                 95.01500
# MSCI BRAZIL                1860.96000
# MSCI CANADA                1990.63000
# MSCI CHINA                   78.71000
# MSCI DENMARK               8227.80500
# MSCI EM ASIA                517.31000
# MSCI EM EU-MIDE-AFRICA      251.16550
# MSCI EM EUROPE              306.43000
# MSCI EM LATIN AMERICA      2598.95500
# MSCI FINLAND                124.12000
# MSCI FRANCE                 147.93000
# MSCI GERMANY                144.64500
# ...

# %%
df.std()
# Out:
# C:\Users\ITS\AppData\Local\Temp/ipykernel_2252/3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# LUXXX                      238.611226
# MSCI ARGENTINA             899.378857
# BLP ORIENTE MEDIO          516.678825
# MSCI AUSTRALIA             101.261295
# MSCI AUSTRIA                24.770889
# MSCI BELGIUM                12.106033
# MSCI BRAZIL                354.986912
# MSCI CANADA                143.502890
# MSCI CHINA                  13.192648
# MSCI DENMARK               978.216958
# MSCI EM ASIA                66.154751
# MSCI EM EU-MIDE-AFRICA      27.880897
# MSCI EM EUROPE              35.676634
# MSCI EM LATIN AMERICA      391.780333
# MSCI FINLAND                 9.374700
# MSCI FRANCE                 14.256886
# MSCI GERMANY                11.913640
# ...

# %%
#calculate the standard deviation of the first five rows 
df.std(axis = 1)[0:5]
# Out:
# C:\Users\ITS\AppData\Local\Temp/ipykernel_2252/4099856511.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std(axis = 1)[0:5]
# 0    2959.163200
# 1    2784.933216
# 2    2686.364752
# 3    2702.525218
# 4    2755.625580
# dtype: float64

# %%
df.min()
# Out:
# Date                      1-Apr-16
# LUXXX                        871.5
# MSCI ARGENTINA              844.09
# BLP ORIENTE MEDIO          1722.87
# MSCI AUSTRALIA              957.15
# MSCI AUSTRIA                 78.29
# MSCI BELGIUM                 57.44
# MSCI BRAZIL                 879.17
# MSCI CANADA                1503.01
# MSCI CHINA                   48.16
# MSCI DENMARK               6671.37
# MSCI EM ASIA                357.16
# MSCI EM EU-MIDE-AFRICA     166.652
# MSCI EM EUROPE              216.88
# MSCI EM LATIN AMERICA      1482.97
# MSCI FINLAND                 93.87
# MSCI FRANCE                 113.79
# MSCI GERMANY                103.11
# MSCI HONG KONG            10473.28
# MSCI INDIA                  873.94
# MSCI ITALY                    42.5
# MSCI JAPAN                  723.88
# MSCI KOREA                   491.8
# MSCI MEXICO                2804.73
# MSCI NETHERLANDS            104.95
# MSCI NEW ZEALAND            110.15
# MSCI NORWAY                2049.32
# ...

# %%
df.min(axis = 1)[0:5]
# Out:
# C:\Users\ITS\AppData\Local\Temp/ipykernel_2252/1481719796.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.min(axis = 1)[0:5]
# 0    59.47
# 1    54.63
# 2    51.54
# 3    51.15
# 4    52.13
# dtype: float64

# %%
df.max()
# Out:
# Date                       9-Sep-16
# LUXXX                       1812.01
# MSCI ARGENTINA              4467.41
# BLP ORIENTE MEDIO         3750.8655
# MSCI AUSTRALIA              1431.46
# MSCI AUSTRIA                 177.58
# MSCI BELGIUM                 107.34
# MSCI BRAZIL                 2404.74
# MSCI CANADA                 2261.28
# MSCI CHINA                   103.54
# MSCI DENMARK               11852.36
# MSCI EM ASIA                 641.63
# MSCI EM EU-MIDE-AFRICA      322.457
# MSCI EM EUROPE               382.64
# MSCI EM LATIN AMERICA       3241.47
# MSCI FINLAND                 136.78
# MSCI FRANCE                  175.35
# MSCI GERMANY                 166.64
# MSCI HONG KONG              16997.4
# MSCI INDIA                  1403.52
# MSCI ITALY                    67.18
# MSCI JAPAN                  1123.82
# MSCI KOREA                   781.63
# MSCI MEXICO                 6145.47
# MSCI NETHERLANDS             178.57
# MSCI NEW ZEALAND             205.44
# ...

# %%
df.max(axis = 1)[0:5]
# Out:
# C:\Users\ITS\AppData\Local\Temp/ipykernel_2252/922250811.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.max(axis = 1)[0:5]
# 0    12080.11
# 1    11438.23
# 2    11063.73
# 3    10654.83
# 4    11002.78
# dtype: float64

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('GWP.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
print(series.head())
# Out:
#                LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA  \
# Date
# 2016-01-01  1390.716         2376.29          3525.9150         1068.79
# 2016-01-08  1291.267         2260.85          3280.6683         1005.56
# 2016-01-15  1257.086         2217.50          3118.2981          985.38
# 2016-01-22  1254.167         2281.98          2935.0677          985.87
# 2016-01-29  1298.240         2462.19          3134.0840         1005.56
#
#             MSCI AUSTRIA  MSCI BELGIUM  MSCI BRAZIL  MSCI CANADA  MSCI CHINA  \
# Date
# 2016-01-01        106.70        105.38      1036.23      1663.27       59.47
# 2016-01-08         97.66         99.35       952.01      1586.18       54.63
# 2016-01-15         93.54         97.32       904.64      1541.08       51.54
# 2016-01-22         95.79        100.73       879.17      1582.10       51.15
# 2016-01-29         96.93        103.05       958.97      1638.84       52.13
#
# ...

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('GWP.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('GWP.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot(style='k.')
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('GWP.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.hist()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('GWP.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series.plot(kind='kde')
pyplot.show()

# %%
# create a scatter plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import lag_plot
series = read_csv('GWP.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
lag_plot(series)
pyplot.show()

# %%
# create an autocorrelation plot
from pandas import read_csv
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
series = read_csv('GWP.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
autocorrelation_plot(series)
pyplot.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("GWP.csv", parse_dates=True, index_col = "Date")
df.head()
# Out:
#                LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA  \
# Date
# 2016-01-01  1390.716         2376.29          3525.9150         1068.79
# 2016-01-08  1291.267         2260.85          3280.6683         1005.56
# 2016-01-15  1257.086         2217.50          3118.2981          985.38
# 2016-01-22  1254.167         2281.98          2935.0677          985.87
# 2016-01-29  1298.240         2462.19          3134.0840         1005.56
#
#             MSCI AUSTRIA  MSCI BELGIUM  MSCI BRAZIL  MSCI CANADA  MSCI CHINA  \
# Date
# 2016-01-01        106.70        105.38      1036.23      1663.27       59.47
# 2016-01-08         97.66         99.35       952.01      1586.18       54.63
# 2016-01-15         93.54         97.32       904.64      1541.08       51.54
# 2016-01-22         95.79        100.73       879.17      1582.10       51.15
# 2016-01-29         96.93        103.05       958.97      1638.84       52.13
#
# ...

# %%
df['LUXXX'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.plot(subplots=True, figsize=(10,12))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
# ...

# %%
import seaborn as sns
#start, end = '2016-01', '2016-12'
fig, axes = plt.subplots(4, 1, figsize=(10, 16), sharex=True)
for name, ax in zip(['LUXXX', 'MSCI INDIA', 'MSCI USA', 'MSCI UK'], axes):
    sns.boxplot(data = df, x='MSCI SPAIN', y=name, ax=ax)
    ax.set_ylabel("")
    ax.set_title(name)
    if ax != axes[-1]:
        ax.set_xlabel('')

# %%
df['LUXXX'].plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.LUXXX.diff().plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
fig, ax = plt.subplots()
ax = df.LUXXX.plot(label='LUXXX')
ax = df.LUXXX.expanding().mean().plot(label='LUXXX expanding mean')
ax = df.LUXXX.expanding().std().plot(label='LUXXX expanding std')
ax.legend()

# %%
# Import those libraries
import pandas as pd
from scipy.stats import pearsonr

# Import your data into Python
df = pd.read_csv("GWP.csv")

# Convert dataframe into series
list1 = df['LUXXX']
list2 = df['MSCI UK']

# Apply the pearsonr()
corr, _ = pearsonr(list1, list2)
print('Pearsons correlation: %.3f' % corr)

# This code is contributed by Amiya Rout
# Out:
# Pearsons correlation: 0.755

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
SuicideRate = pd.read_csv("GWP.csv")
SuicideRate.head()
# Out:
#         Date     LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA  \
# 0   1-Jan-16  1390.716         2376.29          3525.9150         1068.79
# 1   8-Jan-16  1291.267         2260.85          3280.6683         1005.56
# 2  15-Jan-16  1257.086         2217.50          3118.2981          985.38
# 3  22-Jan-16  1254.167         2281.98          2935.0677          985.87
# 4  29-Jan-16  1298.240         2462.19          3134.0840         1005.56
#
#    MSCI AUSTRIA  MSCI BELGIUM  MSCI BRAZIL  MSCI CANADA  MSCI CHINA  ...  \
# 0        106.70        105.38      1036.23      1663.27       59.47  ...
# 1         97.66         99.35       952.01      1586.18       54.63  ...
# 2         93.54         97.32       904.64      1541.08       51.54  ...
# 3         95.79        100.73       879.17      1582.10       51.15  ...
# 4         96.93        103.05       958.97      1638.84       52.13  ...
#
#    MSCI NORWAY  MSCI PERU  MSCI RUSSIA  MSCI SINGAPORE  MSCI SOUTH AFRICA  \
# ...

# %%
pearsoncorr = SuicideRate.corr(method='pearson')
pearsoncorr
# Out:
#                            LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  \
# LUXXX                   1.000000        0.754584           0.823881
# MSCI ARGENTINA          0.754584        1.000000           0.740835
# BLP ORIENTE MEDIO       0.823881        0.740835           1.000000
# MSCI AUSTRALIA          0.046895       -0.160676          -0.124534
# MSCI AUSTRIA            0.674894        0.604493           0.387526
# MSCI BELGIUM            0.850111        0.747766           0.925401
# MSCI BRAZIL             0.337350        0.260126           0.144240
# MSCI CANADA             0.133539       -0.047239          -0.114781
# MSCI CHINA             -0.192526       -0.000917          -0.449813
# MSCI DENMARK           -0.676507       -0.474811          -0.616805
# MSCI EM ASIA           -0.045439        0.110893          -0.312487
# MSCI EM EU-MIDE-AFRICA  0.677351        0.678930           0.492296
# MSCI EM EUROPE          0.380714        0.350046           0.222905
# ...

# %%
import seaborn as sb

# %%
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)
# Out:
# <AxesSubplot:>

# %%
# importing pandas as pd
import pandas as pd

# Making data frame from the csv file
df = pd.read_csv("GWP.csv")

# Printing the first 10 rows of the data frame for visualization
df[:10]
# Out:
#         Date     LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA  \
# 0   1-Jan-16  1390.716         2376.29          3525.9150         1068.79
# 1   8-Jan-16  1291.267         2260.85          3280.6683         1005.56
# 2  15-Jan-16  1257.086         2217.50          3118.2981          985.38
# 3  22-Jan-16  1254.167         2281.98          2935.0677          985.87
# 4  29-Jan-16  1298.240         2462.19          3134.0840         1005.56
# 5   5-Feb-16  1274.632         2478.91          3230.4914         1000.92
# 6  12-Feb-16  1187.171         2396.77          3126.7548          957.15
# 7  19-Feb-16  1269.245         2558.24          3235.5655          997.23
# 8  26-Feb-16  1296.604         2728.83          3256.9893          979.26
# 9   4-Mar-16  1437.405         2677.79          3363.5448         1025.81
#
#    MSCI AUSTRIA  MSCI BELGIUM  MSCI BRAZIL  MSCI CANADA  MSCI CHINA  ...  \
# 0        106.70        105.38      1036.23      1663.27       59.47  ...
# ...

# %%
# To find the correlation among
# the columns using pearson method
df.corr(method ='pearson')
# Out:
#                            LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  \
# LUXXX                   1.000000        0.754584           0.823881
# MSCI ARGENTINA          0.754584        1.000000           0.740835
# BLP ORIENTE MEDIO       0.823881        0.740835           1.000000
# MSCI AUSTRALIA          0.046895       -0.160676          -0.124534
# MSCI AUSTRIA            0.674894        0.604493           0.387526
# MSCI BELGIUM            0.850111        0.747766           0.925401
# MSCI BRAZIL             0.337350        0.260126           0.144240
# MSCI CANADA             0.133539       -0.047239          -0.114781
# MSCI CHINA             -0.192526       -0.000917          -0.449813
# MSCI DENMARK           -0.676507       -0.474811          -0.616805
# MSCI EM ASIA           -0.045439        0.110893          -0.312487
# MSCI EM EU-MIDE-AFRICA  0.677351        0.678930           0.492296
# MSCI EM EUROPE          0.380714        0.350046           0.222905
# ...

# %%
# importing pandas as pd
import pandas as pd

# Making data frame from the csv file
df = pd.read_csv("GWP.csv")

# To find the correlation among
# the columns using kendall method
df.corr(method ='kendall')
# Out:
#                            LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  \
# LUXXX                   1.000000        0.558401           0.580861
# MSCI ARGENTINA          0.558401        1.000000           0.547910
# BLP ORIENTE MEDIO       0.580861        0.547910           1.000000
# MSCI AUSTRALIA          0.026877       -0.091383          -0.117454
# MSCI AUSTRIA            0.457578        0.382000           0.234036
# MSCI BELGIUM            0.533989        0.601097           0.704980
# MSCI BRAZIL             0.110099        0.158351           0.030232
# MSCI CANADA             0.052488       -0.084424          -0.115679
# MSCI CHINA             -0.058753       -0.022009          -0.250095
# MSCI DENMARK           -0.365459       -0.242965          -0.306242
# MSCI EM ASIA            0.018689        0.054548          -0.165373
# MSCI EM EU-MIDE-AFRICA  0.385037        0.442649           0.257325
# MSCI EM EUROPE          0.176063        0.208696           0.108251
# ...

# %%
# Import required libraries
from scipy.stats import kendalltau

# Taking values from the above example in Lists
X = [1, 2, 3, 4, 5, 6, 7]
Y = [1, 3, 6, 2, 7, 4, 5]

# Calculating Kendall Rank correlation
corr, _ = kendalltau(X, Y)
print('Kendall Rank correlation: %.5f' % corr)

# This code is contributed by Amiya Rout
# Out:
# Kendall Rank correlation: 0.42857

# %%
import pandas as pd
df = pd.read_csv('GWP.csv')
print(df)
# Out:
#           Date     LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA  \
# 0     1-Jan-16  1390.716         2376.29          3525.9150         1068.79
# 1     8-Jan-16  1291.267         2260.85          3280.6683         1005.56
# 2    15-Jan-16  1257.086         2217.50          3118.2981          985.38
# 3    22-Jan-16  1254.167         2281.98          2935.0677          985.87
# 4    29-Jan-16  1298.240         2462.19          3134.0840         1005.56
# ..         ...       ...             ...                ...             ...
# 247  25-Sep-20   988.345         1450.64          2252.2500         1166.97
# 248   2-Oct-20  1037.211         1506.32          2265.7000         1128.45
# 249   9-Oct-20  1075.670         1617.45          2214.3200         1187.29
# 250  16-Oct-20  1068.089         1628.12          2194.6300         1200.97
# 251  23-Oct-20  1090.573         1618.83          2185.5500         1201.19
#
# ...

# %%
print(df["LUXXX"].min())
print(df["LUXXX"].max())
print(df["LUXXX"].mean())
# Out:
# 871.5
# 1812.01
# 1457.2319047619035

# %%
print(df.count(0))
# Out:
# Date                      252
# LUXXX                     252
# MSCI ARGENTINA            252
# BLP ORIENTE MEDIO         252
# MSCI AUSTRALIA            252
# MSCI AUSTRIA              252
# MSCI BELGIUM              252
# MSCI BRAZIL               252
# MSCI CANADA               252
# MSCI CHINA                252
# MSCI DENMARK              252
# MSCI EM ASIA              252
# MSCI EM EU-MIDE-AFRICA    252
# MSCI EM EUROPE            252
# MSCI EM LATIN AMERICA     252
# MSCI FINLAND              252
# MSCI FRANCE               252
# MSCI GERMANY              252
# MSCI HONG KONG            252
# MSCI INDIA                252
# MSCI ITALY                252
# MSCI JAPAN                252
# MSCI KOREA                252
# MSCI MEXICO               252
# MSCI NETHERLANDS          252
# MSCI NEW ZEALAND          252
# MSCI NORWAY               252
# MSCI PERU                 252
# MSCI RUSSIA               252
# MSCI SINGAPORE            252
# MSCI SOUTH AFRICA         252
# ...

# %%
print(df.size)
# Out:
# 9072

# %%
a = 5
print(a, "is of type", type(a))

a = 2.0
print(a, "is of type", type(a))

a = 1+2j
print(a, "is complex number?", isinstance(1+2j,complex))
# Out:
# 5 is of type <class 'int'>
# 2.0 is of type <class 'float'>
# (1+2j) is complex number? True

# %%
a = [5,10,15,20,25,30,35,40]

# a[2] = 15
print("a[2] = ", a[2])

# a[0:3] = [5, 10, 15]
print("a[0:3] = ", a[0:3])

# a[5:] = [30, 35, 40]
print("a[5:] = ", a[5:])
# Out:
# a[2] =  15
# a[0:3] =  [5, 10, 15]
# a[5:] =  [30, 35, 40]

# %%
a = [1, 2, 3]
a[2] = 4
print(a)
# Out:
# [1, 2, 4]

# %%
# load and summarize the housing dataset
from pandas import read_csv
from matplotlib import pyplot
# load dataset
url = 'GWP.csv'
dataframe = read_csv(url, header=None)
# summarize shape
print(dataframe.shape)
# summarize first few lines
print(dataframe.head())
# Out:
# (253, 36)
#           0         1               2                  3               4   \
# 0       Date     LUXXX  MSCI ARGENTINA  BLP ORIENTE MEDIO  MSCI AUSTRALIA
# 1   1-Jan-16  1390.716         2376.29           3525.915         1068.79
# 2   8-Jan-16  1291.267         2260.85          3280.6683         1005.56
# 3  15-Jan-16  1257.086          2217.5          3118.2981          985.38
# 4  22-Jan-16  1254.167         2281.98          2935.0677          985.87
#
#              5             6            7            8           9   ...  \
# 0  MSCI AUSTRIA  MSCI BELGIUM  MSCI BRAZIL  MSCI CANADA  MSCI CHINA  ...
# 1         106.7        105.38      1036.23      1663.27       59.47  ...
# 2         97.66         99.35       952.01      1586.18       54.63  ...
# 3         93.54         97.32       904.64      1541.08       51.54  ...
# 4         95.79        100.73       879.17       1582.1       51.15  ...
#
# ...

# %%
# evaluate an lasso regression model on the dataset
from numpy import mean
from numpy import std
from numpy import absolute
from pandas import read_csv
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Lasso
# load the dataset
url = 'GWP.csv'
dataframe = read_csv(url, header=None)
data = dataframe.values
X, y = data[:, :-1], data[:, -1]
# define model
model = Lasso(alpha=1.0)
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# force scores to be positive
scores = absolute(scores)
print('Mean MAE: %.3f (%.3f)' % (mean(scores), std(scores)))
# Out:
# Mean MAE: nan (nan)

# %%
# make a prediction with a lasso regression model on the dataset
from pandas import read_csv
from sklearn.linear_model import Lasso
# load the dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.csv'
dataframe = read_csv(url, header=None)
data = dataframe.values
X, y = data[:, :-1], data[:, -1]
# define model
model = Lasso(alpha=1.0)
# fit model
model.fit(X, y)
# define new data
row = [0.00632,18.00,2.310,0,0.5380,6.5750,65.20,4.0900,1,296.0,15.30,396.90,4.98]
# make a prediction
yhat = model.predict([row])
# summarize prediction
print('Predicted: %.3f' % yhat)
# Out:
# Predicted: 30.998

# %%
# grid search hyperparameters for lasso regression
from numpy import arange
from pandas import read_csv
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedKFold
from sklearn.linear_model import Lasso
# load the dataset
url = 'https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.csv'
dataframe = read_csv(url, header=None)
data = dataframe.values
X, y = data[:, :-1], data[:, -1]
# define model
model = Lasso()
# define model evaluation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid
grid = dict()
grid['alpha'] = arange(0, 1, 0.01)
# define search
search = GridSearchCV(model, grid, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# perform the search
results = search.fit(X, y)
# summarize
print('MAE: %.3f' % results.best_score_)
print('Config: %s' % results.best_params_)
# Out:
# MAE: -3.379
# Config: {'alpha': 0.01}

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale 
from sklearn import model_selection
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
#define URL where data is located
url = "https://raw.githubusercontent.com/Statology/Python-Guides/main/mtcars.csv"

#read in data
data_full = pd.read_csv(url)

#select subset of data
data = data_full[["mpg", "disp", "drat", "wt", "qsec", "hp"]]

#view first six rows of data
data[0:6]
# Out:
#     mpg   disp  drat     wt   qsec   hp
# 0  21.0  160.0  3.90  2.620  16.46  110
# 1  21.0  160.0  3.90  2.875  17.02  110
# 2  22.8  108.0  3.85  2.320  18.61   93
# 3  21.4  258.0  3.08  3.215  19.44  110
# 4  18.7  360.0  3.15  3.440  17.02  175
# 5  18.1  225.0  2.76  3.460  20.22  105

# %%
#define predictor and response variables
X = data[["mpg", "disp", "drat", "wt", "qsec"]]
y = data[["hp"]]

#scale predictor variables
pca = PCA()
X_reduced = pca.fit_transform(scale(X))

#define cross validation method
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

regr = LinearRegression()
mse = []

# Calculate MSE with only the intercept
score = -1*model_selection.cross_val_score(regr,
           np.ones((len(X_reduced),1)), y, cv=cv,
           scoring='neg_mean_squared_error').mean()    
mse.append(score)

# Calculate MSE using cross-validation, adding one component at a time
for i in np.arange(1, 6):
    score = -1*model_selection.cross_val_score(regr,
               X_reduced[:,:i], y, cv=cv, scoring='neg_mean_squared_error').mean()
    mse.append(score)
    
# Plot cross-validation results    
plt.plot(mse)
plt.xlabel('Number of Principal Components')
plt.ylabel('MSE')
plt.title('hp')
# Out:
# Text(0.5, 1.0, 'hp')

# %%
#split the dataset into training (70%) and testing (30%) sets
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=0) 

#scale the training and testing data
X_reduced_train = pca.fit_transform(scale(X_train))
X_reduced_test = pca.transform(scale(X_test))[:,:1]

#train PCR model on training data 
regr = LinearRegression()
regr.fit(X_reduced_train[:,:1], y_train)

#calculate RMSE
pred = regr.predict(X_reduced_test)
np.sqrt(mean_squared_error(y_test, pred))
# Out:
# 40.20964210761152

# %%
import pandas as pd
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# load dataset into Pandas DataFrame
df = pd.read_csv(url, names=['sepal length','sepal width','petal length','petal width','target'])

# %%
from sklearn.preprocessing import StandardScaler
features = ['sepal length', 'sepal width', 'petal length', 'petal width']
# Separating out the features
x = df.loc[:, features].values
# Separating out the target
y = df.loc[:,['target']].values
# Standardizing the features
x = StandardScaler().fit_transform(x)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
finalDf = pd.concat([principalDf, df[['target']]], axis = 1)

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)
targets = ['Iris-setosa', 'Iris-versicolor', 'Iris-virginica']
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['target'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
import numpy as np
from sklearn.decomposition import PCA
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
pca = PCA(n_components=2)
pca.fit(X)

print(pca.explained_variance_ratio_)

print(pca.singular_values_)
# Out:
# [0.99244289 0.00755711]
# [6.30061232 0.54980396]

# %%
pca = PCA(n_components=2, svd_solver='full')
pca.fit(X)

print(pca.explained_variance_ratio_)

print(pca.singular_values_)
# Out:
# [0.99244289 0.00755711]
# [6.30061232 0.54980396]

# %%
pca = PCA(n_components=1, svd_solver='arpack')
pca.fit(X)

print(pca.explained_variance_ratio_)

print(pca.singular_values_)
# Out:
# [0.99244289]
# [6.30061232]

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.decomposition import PCA, IncrementalPCA

iris = load_iris()
X = iris.data
y = iris.target

n_components = 2
ipca = IncrementalPCA(n_components=n_components, batch_size=10)
X_ipca = ipca.fit_transform(X)

pca = PCA(n_components=n_components)
X_pca = pca.fit_transform(X)

colors = ["navy", "turquoise", "darkorange"]

for X_transformed, title in [(X_ipca, "Incremental PCA"), (X_pca, "PCA")]:
    plt.figure(figsize=(8, 8))
    for color, i, target_name in zip(colors, [0, 1, 2], iris.target_names):
        plt.scatter(
            X_transformed[y == i, 0],
            X_transformed[y == i, 1],
            color=color,
            lw=2,
            label=target_name,
        )

    if "Incremental" in title:
        err = np.abs(np.abs(X_pca) - np.abs(X_ipca)).mean()
        plt.title(title + " of iris dataset\nMean absolute unsigned error %.6f" % err)
    else:
        plt.title(title + " of iris dataset")
    plt.legend(loc="best", shadow=False, scatterpoints=1)
    plt.axis([-4, 4, -1.5, 1.5])

plt.show()
